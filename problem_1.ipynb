# %%
# Exercise 1: NASA APOD Data Retrieval and JSON File Processing
# API document: https://github.com/nasa/apod-api
# Date: Nov 15, 2024

# %%
from dotenv import load_dotenv
import json
import time
import os
import requests
import datetime

# %%
# 1. API Call 

# fetch Astronomy Picture of the Day (APOD) data for a specific date using the NASA APOD API.
def get_apod_data(api_key, date):
    
    # define the API endpoint
    url = "https://api.nasa.gov/planetary/apod"
    
    # define request parameters
    params = {
        "api_key": api_key,
        "date": date
    }
    
    try:
        # send the GET request to the API
        response = requests.get(url, params=params)
        
        # check for API key errors (status code 403)
        if response.status_code == 403:
            error_message = response.json().get("error", {}).get("message", "Invalid API key")
            print(f"API Key Validation Error: {error_message}")
            return None
        
        # check for invalid date errors (status code 400)
        if response.status_code == 400:
            error_message = response.json().get("error", {}).get("message", "Invalid date")
            print(f"Date Validation Error: {error_message}")
            return None
        
        # raise an error for bad status codes
        response.raise_for_status()  
        
        # parse the JSON response
        data = response.json()
        
        # extract the required fields
        return {
            "date": data.get("date"),
            "title": data.get("title"),
            "url": data.get("url"),
            "explanation": data.get("explanation"),
            "media_type": data.get("media_type")
        }
    
    except requests.exceptions.RequestException as e:
        print(f"Network error: {e}") # handle network-related errors
    except Exception as e:
        print(f"An error occurred: {e}")  # handle any other exceptions
        
    return None
 

# load the environment variables to retrieve the API key
load_dotenv("api.env")
api_key = os.getenv('API_KEY')

# test the function with a sample date
date = "2020-02-02"
result = get_apod_data(api_key,date)

if result:
    print(f"""
    NASA Astronomy Picture of the Day:
    ----------------------------------
    Date: {result['date']}
    Title: {result['title']}
    Media Type: {result['media_type']}
    URL: {result['url']}
    
    Explanation:
    {result['explanation']}
    """)
# Out:
#     NASA Astronomy Picture of the Day:
#     ----------------------------------
#     Date: 2020-02-02
#     Title: Zeta Oph: Runaway Star
#     Media Type: image
#     URL: https://apod.nasa.gov/apod/image/2002/ZetaOph_spitzer_960.jpg
#
#     Explanation:
#     Like a ship plowing through cosmic seas, runaway star Zeta Ophiuchi produces the arcing interstellar bow wave or bow shock seen in this stunning infrared portrait. In the false-color view, bluish Zeta Oph, a star about 20 times more massive than the Sun, lies near the center of the frame, moving toward the left at 24 kilometers per second. Its strong stellar wind precedes it, compressing and heating the dusty interstellar material and shaping the curved shock front. What set this star in motion? Zeta Oph was likely once a member of a binary star system, its companion star was more massive and hence shorter lived. When the companion exploded as a supernova catastrophically losing mass, Zeta Oph was flung out of the system. About 460 light-years away, Zeta Oph is 65,000 times more luminous than the Sun and would be one of the brighter stars in the sky if it weren't surrounded by obscuring dust. The image spans about 1.5 degrees or 12 light-years at the estimated distance of Zeta Ophiuchi. Last week, NASA placed the Spitzer Space Telescope in safe mode, ending its 16 successful years of studying our universe.    News: NASA’s Spitzer Space Telescope Ends Mission of Astronomical Discovery

# %%
# 2. Fetching Data for a Date Range and 
# 3. Saving Data to a JSON File

# fetche APOD data for a range of dates and saves the data to a JSON file.
def fetch_multiple_apod_data(api_key, start_date, end_date):
    
    try:
        # validate the date format
        start = datetime.datetime.strptime(start_date, "%Y-%m-%d")
        end = datetime.datetime.strptime(end_date, "%Y-%m-%d")
        
        # check the date range is valid
        if start > end:
            print("Error: Start date must be earlier than or equal to the end date.")
            return None   
            
        # ensure dates are within NASA APOD API's allowed range
        if start < datetime.datetime(1995, 6, 16) or end > datetime.datetime.today():
            print("Error: Dates must be between 1995-06-16 and today's date.")
            return None
        
        # define the output JSON file
        output_file = "apod_data.json"
        
        # load existing data from the JSON file 
        try:
            with open(output_file, "r") as file:
                all_data = json.load(file)
        except FileNotFoundError:
            all_data = []
        
        # iterate through the date range
        current_date = start
        successful_dates = []
        while current_date <= end:
            # convert the current date to a string
            date_str = current_date.strftime("%Y-%m-%d")
            print(f"Fetching data for {date_str}...")
            
            apod_data = get_apod_data(api_key, date_str)
            
            if apod_data:
                # append the new data to the list
                all_data.append(apod_data)
                
                # write the updated list to the file
                try: 
                    with open(output_file, "w") as file:
                        json.dump(all_data, file, indent=4)
                    print(f"Data for {date_str} written to {output_file}.")
                    successful_dates.append(date_str)
                except PermissionError:
                    print(f"Permission denied: Unable to write to {output_file}. Check file permissions.")
                    return None
                except IOError as io_error: 
                    print(f"File I/O error: {io_error}. Unable to write to {output_file}.")
                    return None
            else:
                print(f"No data available for {date_str}. Skipping...")
        
            # respect the API rate limit with a delay
            time.sleep(1)
            
            # move to the next day
            current_date += datetime.timedelta(days=1)

        print(f"Data fetching completed. {len(successful_dates)} records saved to {output_file}.")
        return all_data
        
    except ValueError as e:
        # handle invalid data format errors
        print(f"Error: {e}. Please ensure the dates are in YYYY-MM-DD format.")
        return None
    except Exception as e:
        # handle any other exception
        print(f"An unexpected error occurred: {e}")  
        return None
 
# load the environment variables to retrieve the API key
load_dotenv("api.env")
api_key = os.getenv('API_KEY')   

# define the start and end dates
start_date = "2020-01-01"
end_date = "2020-12-31"  

# call the function 
result = fetch_multiple_apod_data(api_key, start_date, end_date)

if result:
    print("Data successfully retrieved and processed.")
else:
    print("\nNo data was retrieved. Please check your API key, date range, or network connection.")
# Out:
# Fetching data for 2020-01-01...
# Data for 2020-01-01 written to apod_data.json.
# Fetching data for 2020-01-02...
# Data for 2020-01-02 written to apod_data.json.
# Fetching data for 2020-01-03...
# Data for 2020-01-03 written to apod_data.json.
# Fetching data for 2020-01-04...
# Data for 2020-01-04 written to apod_data.json.
# Fetching data for 2020-01-05...
# Data for 2020-01-05 written to apod_data.json.
# Fetching data for 2020-01-06...
# Data for 2020-01-06 written to apod_data.json.
# Fetching data for 2020-01-07...
# Data for 2020-01-07 written to apod_data.json.
# Fetching data for 2020-01-08...
# Data for 2020-01-08 written to apod_data.json.
# Fetching data for 2020-01-09...
# Data for 2020-01-09 written to apod_data.json.
# Fetching data for 2020-01-10...
# Data for 2020-01-10 written to apod_data.json.
# Fetching data for 2020-01-11...
# Data for 2020-01-11 written to apod_data.json.
# Fetching data for 2020-01-12...
# Data for 2020-01-12 written to apod_data.json.
# Fetching data for 2020-01-13...
# Data for 2020-01-13 written to apod_data.json.
# Fetching data for 2020-01-14...
# Data for 2020-01-14 written to apod_data.json.
# Fetching data for 2020-01-15...
# Data for 2020-01-15 written to apod_data.json.
# Fetching data for 2020-01-16...
# Data for 2020-01-16 written to apod_data.json.
# Fetching data for 2020-01-17...
# Data for 2020-01-17 written to apod_data.json.
# Fetching data for 2020-01-18...
# Data for 2020-01-18 written to apod_data.json.
# Fetching data for 2020-01-19...
# Data for 2020-01-19 written to apod_data.json.
# Fetching data for 2020-01-20...
# Data for 2020-01-20 written to apod_data.json.
# Fetching data for 2020-01-21...
# Data for 2020-01-21 written to apod_data.json.
# Fetching data for 2020-01-22...
# Data for 2020-01-22 written to apod_data.json.
# Fetching data for 2020-01-23...
# Data for 2020-01-23 written to apod_data.json.
# Fetching data for 2020-01-24...
# Data for 2020-01-24 written to apod_data.json.
# Fetching data for 2020-01-25...
# Data for 2020-01-25 written to apod_data.json.
# Fetching data for 2020-01-26...
# Data for 2020-01-26 written to apod_data.json.
# Fetching data for 2020-01-27...
# Data for 2020-01-27 written to apod_data.json.
# Fetching data for 2020-01-28...
# Data for 2020-01-28 written to apod_data.json.
# Fetching data for 2020-01-29...
# Data for 2020-01-29 written to apod_data.json.
# Fetching data for 2020-01-30...
# Data for 2020-01-30 written to apod_data.json.
# Fetching data for 2020-01-31...
# Data for 2020-01-31 written to apod_data.json.
# Fetching data for 2020-02-01...
# Data for 2020-02-01 written to apod_data.json.
# Fetching data for 2020-02-02...
# Data for 2020-02-02 written to apod_data.json.
# Fetching data for 2020-02-03...
# Data for 2020-02-03 written to apod_data.json.
# Fetching data for 2020-02-04...
# Data for 2020-02-04 written to apod_data.json.
# Fetching data for 2020-02-05...
# Data for 2020-02-05 written to apod_data.json.
# Fetching data for 2020-02-06...
# Data for 2020-02-06 written to apod_data.json.
# Fetching data for 2020-02-07...
# Data for 2020-02-07 written to apod_data.json.
# Fetching data for 2020-02-08...
# Data for 2020-02-08 written to apod_data.json.
# Fetching data for 2020-02-09...
# Data for 2020-02-09 written to apod_data.json.
# Fetching data for 2020-02-10...
# Data for 2020-02-10 written to apod_data.json.
# Fetching data for 2020-02-11...
# Data for 2020-02-11 written to apod_data.json.
# Fetching data for 2020-02-12...
# Data for 2020-02-12 written to apod_data.json.
# Fetching data for 2020-02-13...
# Data for 2020-02-13 written to apod_data.json.
# Fetching data for 2020-02-14...
# Data for 2020-02-14 written to apod_data.json.
# Fetching data for 2020-02-15...
# Data for 2020-02-15 written to apod_data.json.
# Fetching data for 2020-02-16...
# Data for 2020-02-16 written to apod_data.json.
# Fetching data for 2020-02-17...
# Data for 2020-02-17 written to apod_data.json.
# Fetching data for 2020-02-18...
# Data for 2020-02-18 written to apod_data.json.
# Fetching data for 2020-02-19...
# Data for 2020-02-19 written to apod_data.json.
# Fetching data for 2020-02-20...
# Data for 2020-02-20 written to apod_data.json.
# Fetching data for 2020-02-21...
# Data for 2020-02-21 written to apod_data.json.
# Fetching data for 2020-02-22...
# Data for 2020-02-22 written to apod_data.json.
# Fetching data for 2020-02-23...
# Data for 2020-02-23 written to apod_data.json.
# Fetching data for 2020-02-24...
# Data for 2020-02-24 written to apod_data.json.
# Fetching data for 2020-02-25...
# Data for 2020-02-25 written to apod_data.json.
# Fetching data for 2020-02-26...
# Data for 2020-02-26 written to apod_data.json.
# Fetching data for 2020-02-27...
# Data for 2020-02-27 written to apod_data.json.
# Fetching data for 2020-02-28...
# Data for 2020-02-28 written to apod_data.json.
# Fetching data for 2020-02-29...
# Data for 2020-02-29 written to apod_data.json.
# Fetching data for 2020-03-01...
# Data for 2020-03-01 written to apod_data.json.
# Fetching data for 2020-03-02...
# Data for 2020-03-02 written to apod_data.json.
# Fetching data for 2020-03-03...
# Data for 2020-03-03 written to apod_data.json.
# Fetching data for 2020-03-04...
# Data for 2020-03-04 written to apod_data.json.
# Fetching data for 2020-03-05...
# Data for 2020-03-05 written to apod_data.json.
# Fetching data for 2020-03-06...
# Data for 2020-03-06 written to apod_data.json.
# Fetching data for 2020-03-07...
# Data for 2020-03-07 written to apod_data.json.
# Fetching data for 2020-03-08...
# Data for 2020-03-08 written to apod_data.json.
# Fetching data for 2020-03-09...
# Data for 2020-03-09 written to apod_data.json.
# Fetching data for 2020-03-10...
# Data for 2020-03-10 written to apod_data.json.
# Fetching data for 2020-03-11...
# Data for 2020-03-11 written to apod_data.json.
# Fetching data for 2020-03-12...
# Data for 2020-03-12 written to apod_data.json.
# Fetching data for 2020-03-13...
# Data for 2020-03-13 written to apod_data.json.
# Fetching data for 2020-03-14...
# Data for 2020-03-14 written to apod_data.json.
# Fetching data for 2020-03-15...
# Data for 2020-03-15 written to apod_data.json.
# Fetching data for 2020-03-16...
# Data for 2020-03-16 written to apod_data.json.
# Fetching data for 2020-03-17...
# Data for 2020-03-17 written to apod_data.json.
# Fetching data for 2020-03-18...
# Data for 2020-03-18 written to apod_data.json.
# Fetching data for 2020-03-19...
# Data for 2020-03-19 written to apod_data.json.
# Fetching data for 2020-03-20...
# Data for 2020-03-20 written to apod_data.json.
# Fetching data for 2020-03-21...
# Data for 2020-03-21 written to apod_data.json.
# Fetching data for 2020-03-22...
# Data for 2020-03-22 written to apod_data.json.
# Fetching data for 2020-03-23...
# Data for 2020-03-23 written to apod_data.json.
# Fetching data for 2020-03-24...
# Data for 2020-03-24 written to apod_data.json.
# Fetching data for 2020-03-25...
# Data for 2020-03-25 written to apod_data.json.
# Fetching data for 2020-03-26...
# Data for 2020-03-26 written to apod_data.json.
# Fetching data for 2020-03-27...
# Data for 2020-03-27 written to apod_data.json.
# Fetching data for 2020-03-28...
# Data for 2020-03-28 written to apod_data.json.
# Fetching data for 2020-03-29...
# Data for 2020-03-29 written to apod_data.json.
# Fetching data for 2020-03-30...
# Data for 2020-03-30 written to apod_data.json.
# Fetching data for 2020-03-31...
# Data for 2020-03-31 written to apod_data.json.
# Fetching data for 2020-04-01...
# Data for 2020-04-01 written to apod_data.json.
# Fetching data for 2020-04-02...
# Data for 2020-04-02 written to apod_data.json.
# Fetching data for 2020-04-03...
# Data for 2020-04-03 written to apod_data.json.
# Fetching data for 2020-04-04...
# Data for 2020-04-04 written to apod_data.json.
# Fetching data for 2020-04-05...
# Data for 2020-04-05 written to apod_data.json.
# Fetching data for 2020-04-06...
# Data for 2020-04-06 written to apod_data.json.
# Fetching data for 2020-04-07...
# Data for 2020-04-07 written to apod_data.json.
# Fetching data for 2020-04-08...
# Data for 2020-04-08 written to apod_data.json.
# Fetching data for 2020-04-09...
# Data for 2020-04-09 written to apod_data.json.
# Fetching data for 2020-04-10...
# Data for 2020-04-10 written to apod_data.json.
# Fetching data for 2020-04-11...
# Data for 2020-04-11 written to apod_data.json.
# Fetching data for 2020-04-12...
# Data for 2020-04-12 written to apod_data.json.
# Fetching data for 2020-04-13...
# Data for 2020-04-13 written to apod_data.json.
# Fetching data for 2020-04-14...
# Data for 2020-04-14 written to apod_data.json.
# Fetching data for 2020-04-15...
# Data for 2020-04-15 written to apod_data.json.
# Fetching data for 2020-04-16...
# Data for 2020-04-16 written to apod_data.json.
# Fetching data for 2020-04-17...
# Data for 2020-04-17 written to apod_data.json.
# Fetching data for 2020-04-18...
# Data for 2020-04-18 written to apod_data.json.
# Fetching data for 2020-04-19...
# Data for 2020-04-19 written to apod_data.json.
# Fetching data for 2020-04-20...
# Data for 2020-04-20 written to apod_data.json.
# Fetching data for 2020-04-21...
# Data for 2020-04-21 written to apod_data.json.
# Fetching data for 2020-04-22...
# Data for 2020-04-22 written to apod_data.json.
# Fetching data for 2020-04-23...
# Data for 2020-04-23 written to apod_data.json.
# Fetching data for 2020-04-24...
# Data for 2020-04-24 written to apod_data.json.
# Fetching data for 2020-04-25...
# Data for 2020-04-25 written to apod_data.json.
# Fetching data for 2020-04-26...
# Data for 2020-04-26 written to apod_data.json.
# Fetching data for 2020-04-27...
# Data for 2020-04-27 written to apod_data.json.
# Fetching data for 2020-04-28...
# Data for 2020-04-28 written to apod_data.json.
# Fetching data for 2020-04-29...
# Data for 2020-04-29 written to apod_data.json.
# Fetching data for 2020-04-30...
# Data for 2020-04-30 written to apod_data.json.
# Fetching data for 2020-05-01...
# Data for 2020-05-01 written to apod_data.json.
# Fetching data for 2020-05-02...
# Data for 2020-05-02 written to apod_data.json.
# Fetching data for 2020-05-03...
# Data for 2020-05-03 written to apod_data.json.
# Fetching data for 2020-05-04...
# Data for 2020-05-04 written to apod_data.json.
# Fetching data for 2020-05-05...
# Data for 2020-05-05 written to apod_data.json.
# Fetching data for 2020-05-06...
# Data for 2020-05-06 written to apod_data.json.
# Fetching data for 2020-05-07...
# Data for 2020-05-07 written to apod_data.json.
# Fetching data for 2020-05-08...
# Data for 2020-05-08 written to apod_data.json.
# Fetching data for 2020-05-09...
# Data for 2020-05-09 written to apod_data.json.
# Fetching data for 2020-05-10...
# Data for 2020-05-10 written to apod_data.json.
# Fetching data for 2020-05-11...
# Data for 2020-05-11 written to apod_data.json.
# Fetching data for 2020-05-12...
# Data for 2020-05-12 written to apod_data.json.
# Fetching data for 2020-05-13...
# Data for 2020-05-13 written to apod_data.json.
# Fetching data for 2020-05-14...
# Data for 2020-05-14 written to apod_data.json.
# Fetching data for 2020-05-15...
# Data for 2020-05-15 written to apod_data.json.
# Fetching data for 2020-05-16...
# Data for 2020-05-16 written to apod_data.json.
# Fetching data for 2020-05-17...
# Data for 2020-05-17 written to apod_data.json.
# Fetching data for 2020-05-18...
# Data for 2020-05-18 written to apod_data.json.
# Fetching data for 2020-05-19...
# Data for 2020-05-19 written to apod_data.json.
# Fetching data for 2020-05-20...
# Data for 2020-05-20 written to apod_data.json.
# Fetching data for 2020-05-21...
# Data for 2020-05-21 written to apod_data.json.
# Fetching data for 2020-05-22...
# Data for 2020-05-22 written to apod_data.json.
# Fetching data for 2020-05-23...
# Data for 2020-05-23 written to apod_data.json.
# Fetching data for 2020-05-24...
# Data for 2020-05-24 written to apod_data.json.
# Fetching data for 2020-05-25...
# Data for 2020-05-25 written to apod_data.json.
# Fetching data for 2020-05-26...
# Data for 2020-05-26 written to apod_data.json.
# Fetching data for 2020-05-27...
# Data for 2020-05-27 written to apod_data.json.
# Fetching data for 2020-05-28...
# Data for 2020-05-28 written to apod_data.json.
# Fetching data for 2020-05-29...
# Data for 2020-05-29 written to apod_data.json.
# Fetching data for 2020-05-30...
# Data for 2020-05-30 written to apod_data.json.
# Fetching data for 2020-05-31...
# Data for 2020-05-31 written to apod_data.json.
# Fetching data for 2020-06-01...
# Data for 2020-06-01 written to apod_data.json.
# Fetching data for 2020-06-02...
# Data for 2020-06-02 written to apod_data.json.
# Fetching data for 2020-06-03...
# Data for 2020-06-03 written to apod_data.json.
# Fetching data for 2020-06-04...
# Data for 2020-06-04 written to apod_data.json.
# Fetching data for 2020-06-05...
# Data for 2020-06-05 written to apod_data.json.
# Fetching data for 2020-06-06...
# Data for 2020-06-06 written to apod_data.json.
# Fetching data for 2020-06-07...
# Data for 2020-06-07 written to apod_data.json.
# Fetching data for 2020-06-08...
# Data for 2020-06-08 written to apod_data.json.
# Fetching data for 2020-06-09...
# Data for 2020-06-09 written to apod_data.json.
# Fetching data for 2020-06-10...
# Network error: 404 Client Error: Not Found for url: https://api.nasa.gov/planetary/apod?api_key=AdyflA9fKwyKTOn48E9WqUWKxuEPl87YQ8DQ7tWW&date=2020-06-10
# No data available for 2020-06-10. Skipping...
# Fetching data for 2020-06-11...
# Data for 2020-06-11 written to apod_data.json.
# Fetching data for 2020-06-12...
# Data for 2020-06-12 written to apod_data.json.
# Fetching data for 2020-06-13...
# Data for 2020-06-13 written to apod_data.json.
# Fetching data for 2020-06-14...
# Data for 2020-06-14 written to apod_data.json.
# Fetching data for 2020-06-15...
# Data for 2020-06-15 written to apod_data.json.
# Fetching data for 2020-06-16...
# Data for 2020-06-16 written to apod_data.json.
# Fetching data for 2020-06-17...
# Data for 2020-06-17 written to apod_data.json.
# Fetching data for 2020-06-18...
# Data for 2020-06-18 written to apod_data.json.
# Fetching data for 2020-06-19...
# Data for 2020-06-19 written to apod_data.json.
# Fetching data for 2020-06-20...
# Data for 2020-06-20 written to apod_data.json.
# Fetching data for 2020-06-21...
# Data for 2020-06-21 written to apod_data.json.
# Fetching data for 2020-06-22...
# Data for 2020-06-22 written to apod_data.json.
# Fetching data for 2020-06-23...
# Data for 2020-06-23 written to apod_data.json.
# Fetching data for 2020-06-24...
# Data for 2020-06-24 written to apod_data.json.
# Fetching data for 2020-06-25...
# Data for 2020-06-25 written to apod_data.json.
# Fetching data for 2020-06-26...
# Data for 2020-06-26 written to apod_data.json.
# Fetching data for 2020-06-27...
# Data for 2020-06-27 written to apod_data.json.
# Fetching data for 2020-06-28...
# Data for 2020-06-28 written to apod_data.json.
# Fetching data for 2020-06-29...
# Data for 2020-06-29 written to apod_data.json.
# Fetching data for 2020-06-30...
# Data for 2020-06-30 written to apod_data.json.
# Fetching data for 2020-07-01...
# Data for 2020-07-01 written to apod_data.json.
# Fetching data for 2020-07-02...
# Data for 2020-07-02 written to apod_data.json.
# Fetching data for 2020-07-03...
# Data for 2020-07-03 written to apod_data.json.
# Fetching data for 2020-07-04...
# Data for 2020-07-04 written to apod_data.json.
# Fetching data for 2020-07-05...
# Data for 2020-07-05 written to apod_data.json.
# Fetching data for 2020-07-06...
# Data for 2020-07-06 written to apod_data.json.
# Fetching data for 2020-07-07...
# Data for 2020-07-07 written to apod_data.json.
# Fetching data for 2020-07-08...
# Data for 2020-07-08 written to apod_data.json.
# Fetching data for 2020-07-09...
# Data for 2020-07-09 written to apod_data.json.
# Fetching data for 2020-07-10...
# Data for 2020-07-10 written to apod_data.json.
# Fetching data for 2020-07-11...
# Data for 2020-07-11 written to apod_data.json.
# Fetching data for 2020-07-12...
# Data for 2020-07-12 written to apod_data.json.
# Fetching data for 2020-07-13...
# Data for 2020-07-13 written to apod_data.json.
# Fetching data for 2020-07-14...
# Data for 2020-07-14 written to apod_data.json.
# Fetching data for 2020-07-15...
# Data for 2020-07-15 written to apod_data.json.
# Fetching data for 2020-07-16...
# Data for 2020-07-16 written to apod_data.json.
# Fetching data for 2020-07-17...
# Data for 2020-07-17 written to apod_data.json.
# Fetching data for 2020-07-18...
# Data for 2020-07-18 written to apod_data.json.
# Fetching data for 2020-07-19...
# Data for 2020-07-19 written to apod_data.json.
# Fetching data for 2020-07-20...
# Data for 2020-07-20 written to apod_data.json.
# Fetching data for 2020-07-21...
# Data for 2020-07-21 written to apod_data.json.
# Fetching data for 2020-07-22...
# Data for 2020-07-22 written to apod_data.json.
# Fetching data for 2020-07-23...
# Data for 2020-07-23 written to apod_data.json.
# Fetching data for 2020-07-24...
# Data for 2020-07-24 written to apod_data.json.
# Fetching data for 2020-07-25...
# Data for 2020-07-25 written to apod_data.json.
# Fetching data for 2020-07-26...
# Data for 2020-07-26 written to apod_data.json.
# Fetching data for 2020-07-27...
# Data for 2020-07-27 written to apod_data.json.
# Fetching data for 2020-07-28...
# Data for 2020-07-28 written to apod_data.json.
# Fetching data for 2020-07-29...
# Data for 2020-07-29 written to apod_data.json.
# Fetching data for 2020-07-30...
# Data for 2020-07-30 written to apod_data.json.
# Fetching data for 2020-07-31...
# Data for 2020-07-31 written to apod_data.json.
# Fetching data for 2020-08-01...
# Data for 2020-08-01 written to apod_data.json.
# Fetching data for 2020-08-02...
# Data for 2020-08-02 written to apod_data.json.
# Fetching data for 2020-08-03...
# Data for 2020-08-03 written to apod_data.json.
# Fetching data for 2020-08-04...
# Data for 2020-08-04 written to apod_data.json.
# Fetching data for 2020-08-05...
# Data for 2020-08-05 written to apod_data.json.
# Fetching data for 2020-08-06...
# Data for 2020-08-06 written to apod_data.json.
# Fetching data for 2020-08-07...
# Data for 2020-08-07 written to apod_data.json.
# Fetching data for 2020-08-08...
# Data for 2020-08-08 written to apod_data.json.
# Fetching data for 2020-08-09...
# Data for 2020-08-09 written to apod_data.json.
# Fetching data for 2020-08-10...
# Data for 2020-08-10 written to apod_data.json.
# Fetching data for 2020-08-11...
# Data for 2020-08-11 written to apod_data.json.
# Fetching data for 2020-08-12...
# Data for 2020-08-12 written to apod_data.json.
# Fetching data for 2020-08-13...
# Data for 2020-08-13 written to apod_data.json.
# Fetching data for 2020-08-14...
# Data for 2020-08-14 written to apod_data.json.
# Fetching data for 2020-08-15...
# Data for 2020-08-15 written to apod_data.json.
# Fetching data for 2020-08-16...
# Data for 2020-08-16 written to apod_data.json.
# Fetching data for 2020-08-17...
# Data for 2020-08-17 written to apod_data.json.
# Fetching data for 2020-08-18...
# Data for 2020-08-18 written to apod_data.json.
# Fetching data for 2020-08-19...
# Data for 2020-08-19 written to apod_data.json.
# Fetching data for 2020-08-20...
# Data for 2020-08-20 written to apod_data.json.
# Fetching data for 2020-08-21...
# Data for 2020-08-21 written to apod_data.json.
# Fetching data for 2020-08-22...
# Data for 2020-08-22 written to apod_data.json.
# Fetching data for 2020-08-23...
# Data for 2020-08-23 written to apod_data.json.
# Fetching data for 2020-08-24...
# Data for 2020-08-24 written to apod_data.json.
# Fetching data for 2020-08-25...
# Data for 2020-08-25 written to apod_data.json.
# Fetching data for 2020-08-26...
# Data for 2020-08-26 written to apod_data.json.
# Fetching data for 2020-08-27...
# Data for 2020-08-27 written to apod_data.json.
# Fetching data for 2020-08-28...
# Data for 2020-08-28 written to apod_data.json.
# Fetching data for 2020-08-29...
# Data for 2020-08-29 written to apod_data.json.
# Fetching data for 2020-08-30...
# Data for 2020-08-30 written to apod_data.json.
# Fetching data for 2020-08-31...
# Data for 2020-08-31 written to apod_data.json.
# Fetching data for 2020-09-01...
# Data for 2020-09-01 written to apod_data.json.
# Fetching data for 2020-09-02...
# Data for 2020-09-02 written to apod_data.json.
# Fetching data for 2020-09-03...
# Data for 2020-09-03 written to apod_data.json.
# Fetching data for 2020-09-04...
# Data for 2020-09-04 written to apod_data.json.
# Fetching data for 2020-09-05...
# Data for 2020-09-05 written to apod_data.json.
# Fetching data for 2020-09-06...
# Data for 2020-09-06 written to apod_data.json.
# Fetching data for 2020-09-07...
# Data for 2020-09-07 written to apod_data.json.
# Fetching data for 2020-09-08...
# Data for 2020-09-08 written to apod_data.json.
# Fetching data for 2020-09-09...
# Data for 2020-09-09 written to apod_data.json.
# Fetching data for 2020-09-10...
# Data for 2020-09-10 written to apod_data.json.
# Fetching data for 2020-09-11...
# Data for 2020-09-11 written to apod_data.json.
# Fetching data for 2020-09-12...
# Data for 2020-09-12 written to apod_data.json.
# Fetching data for 2020-09-13...
# Data for 2020-09-13 written to apod_data.json.
# Fetching data for 2020-09-14...
# Data for 2020-09-14 written to apod_data.json.
# Fetching data for 2020-09-15...
# Data for 2020-09-15 written to apod_data.json.
# Fetching data for 2020-09-16...
# Data for 2020-09-16 written to apod_data.json.
# Fetching data for 2020-09-17...
# Data for 2020-09-17 written to apod_data.json.
# Fetching data for 2020-09-18...
# Data for 2020-09-18 written to apod_data.json.
# Fetching data for 2020-09-19...
# Data for 2020-09-19 written to apod_data.json.
# Fetching data for 2020-09-20...
# Data for 2020-09-20 written to apod_data.json.
# Fetching data for 2020-09-21...
# Data for 2020-09-21 written to apod_data.json.
# Fetching data for 2020-09-22...
# Data for 2020-09-22 written to apod_data.json.
# Fetching data for 2020-09-23...
# Data for 2020-09-23 written to apod_data.json.
# Fetching data for 2020-09-24...
# Data for 2020-09-24 written to apod_data.json.
# Fetching data for 2020-09-25...
# Data for 2020-09-25 written to apod_data.json.
# Fetching data for 2020-09-26...
# Data for 2020-09-26 written to apod_data.json.
# Fetching data for 2020-09-27...
# Data for 2020-09-27 written to apod_data.json.
# Fetching data for 2020-09-28...
# Data for 2020-09-28 written to apod_data.json.
# Fetching data for 2020-09-29...
# Data for 2020-09-29 written to apod_data.json.
# Fetching data for 2020-09-30...
# Data for 2020-09-30 written to apod_data.json.
# Fetching data for 2020-10-01...
# Data for 2020-10-01 written to apod_data.json.
# Fetching data for 2020-10-02...
# Data for 2020-10-02 written to apod_data.json.
# Fetching data for 2020-10-03...
# Data for 2020-10-03 written to apod_data.json.
# Fetching data for 2020-10-04...
# Data for 2020-10-04 written to apod_data.json.
# Fetching data for 2020-10-05...
# Data for 2020-10-05 written to apod_data.json.
# Fetching data for 2020-10-06...
# Data for 2020-10-06 written to apod_data.json.
# Fetching data for 2020-10-07...
# Data for 2020-10-07 written to apod_data.json.
# Fetching data for 2020-10-08...
# Data for 2020-10-08 written to apod_data.json.
# Fetching data for 2020-10-09...
# Data for 2020-10-09 written to apod_data.json.
# Fetching data for 2020-10-10...
# Data for 2020-10-10 written to apod_data.json.
# Fetching data for 2020-10-11...
# Data for 2020-10-11 written to apod_data.json.
# Fetching data for 2020-10-12...
# Data for 2020-10-12 written to apod_data.json.
# Fetching data for 2020-10-13...
# Data for 2020-10-13 written to apod_data.json.
# Fetching data for 2020-10-14...
# Data for 2020-10-14 written to apod_data.json.
# Fetching data for 2020-10-15...
# Data for 2020-10-15 written to apod_data.json.
# Fetching data for 2020-10-16...
# Data for 2020-10-16 written to apod_data.json.
# Fetching data for 2020-10-17...
# Data for 2020-10-17 written to apod_data.json.
# Fetching data for 2020-10-18...
# Data for 2020-10-18 written to apod_data.json.
# Fetching data for 2020-10-19...
# Data for 2020-10-19 written to apod_data.json.
# Fetching data for 2020-10-20...
# Data for 2020-10-20 written to apod_data.json.
# Fetching data for 2020-10-21...
# Data for 2020-10-21 written to apod_data.json.
# Fetching data for 2020-10-22...
# Data for 2020-10-22 written to apod_data.json.
# Fetching data for 2020-10-23...
# Data for 2020-10-23 written to apod_data.json.
# Fetching data for 2020-10-24...
# Data for 2020-10-24 written to apod_data.json.
# Fetching data for 2020-10-25...
# Data for 2020-10-25 written to apod_data.json.
# Fetching data for 2020-10-26...
# Data for 2020-10-26 written to apod_data.json.
# Fetching data for 2020-10-27...
# Data for 2020-10-27 written to apod_data.json.
# Fetching data for 2020-10-28...
# Data for 2020-10-28 written to apod_data.json.
# Fetching data for 2020-10-29...
# Data for 2020-10-29 written to apod_data.json.
# Fetching data for 2020-10-30...
# Data for 2020-10-30 written to apod_data.json.
# Fetching data for 2020-10-31...
# Data for 2020-10-31 written to apod_data.json.
# Fetching data for 2020-11-01...
# Data for 2020-11-01 written to apod_data.json.
# Fetching data for 2020-11-02...
# Data for 2020-11-02 written to apod_data.json.
# Fetching data for 2020-11-03...
# Data for 2020-11-03 written to apod_data.json.
# Fetching data for 2020-11-04...
# Data for 2020-11-04 written to apod_data.json.
# Fetching data for 2020-11-05...
# Data for 2020-11-05 written to apod_data.json.
# Fetching data for 2020-11-06...
# Data for 2020-11-06 written to apod_data.json.
# Fetching data for 2020-11-07...
# Data for 2020-11-07 written to apod_data.json.
# Fetching data for 2020-11-08...
# Data for 2020-11-08 written to apod_data.json.
# Fetching data for 2020-11-09...
# Data for 2020-11-09 written to apod_data.json.
# Fetching data for 2020-11-10...
# Data for 2020-11-10 written to apod_data.json.
# Fetching data for 2020-11-11...
# Data for 2020-11-11 written to apod_data.json.
# Fetching data for 2020-11-12...
# Data for 2020-11-12 written to apod_data.json.
# Fetching data for 2020-11-13...
# Data for 2020-11-13 written to apod_data.json.
# Fetching data for 2020-11-14...
# Data for 2020-11-14 written to apod_data.json.
# Fetching data for 2020-11-15...
# Data for 2020-11-15 written to apod_data.json.
# Fetching data for 2020-11-16...
# Data for 2020-11-16 written to apod_data.json.
# Fetching data for 2020-11-17...
# Data for 2020-11-17 written to apod_data.json.
# Fetching data for 2020-11-18...
# Data for 2020-11-18 written to apod_data.json.
# Fetching data for 2020-11-19...
# Data for 2020-11-19 written to apod_data.json.
# Fetching data for 2020-11-20...
# Data for 2020-11-20 written to apod_data.json.
# Fetching data for 2020-11-21...
# Data for 2020-11-21 written to apod_data.json.
# Fetching data for 2020-11-22...
# Data for 2020-11-22 written to apod_data.json.
# Fetching data for 2020-11-23...
# Data for 2020-11-23 written to apod_data.json.
# Fetching data for 2020-11-24...
# Data for 2020-11-24 written to apod_data.json.
# Fetching data for 2020-11-25...
# Data for 2020-11-25 written to apod_data.json.
# Fetching data for 2020-11-26...
# Data for 2020-11-26 written to apod_data.json.
# Fetching data for 2020-11-27...
# Data for 2020-11-27 written to apod_data.json.
# Fetching data for 2020-11-28...
# Data for 2020-11-28 written to apod_data.json.
# Fetching data for 2020-11-29...
# Data for 2020-11-29 written to apod_data.json.
# Fetching data for 2020-11-30...
# Data for 2020-11-30 written to apod_data.json.
# Fetching data for 2020-12-01...
# Data for 2020-12-01 written to apod_data.json.
# Fetching data for 2020-12-02...
# Data for 2020-12-02 written to apod_data.json.
# Fetching data for 2020-12-03...
# Data for 2020-12-03 written to apod_data.json.
# Fetching data for 2020-12-04...
# Data for 2020-12-04 written to apod_data.json.
# Fetching data for 2020-12-05...
# Data for 2020-12-05 written to apod_data.json.
# Fetching data for 2020-12-06...
# Data for 2020-12-06 written to apod_data.json.
# Fetching data for 2020-12-07...
# Data for 2020-12-07 written to apod_data.json.
# Fetching data for 2020-12-08...
# Data for 2020-12-08 written to apod_data.json.
# Fetching data for 2020-12-09...
# Data for 2020-12-09 written to apod_data.json.
# Fetching data for 2020-12-10...
# Data for 2020-12-10 written to apod_data.json.
# Fetching data for 2020-12-11...
# Data for 2020-12-11 written to apod_data.json.
# Fetching data for 2020-12-12...
# Data for 2020-12-12 written to apod_data.json.
# Fetching data for 2020-12-13...
# Data for 2020-12-13 written to apod_data.json.
# Fetching data for 2020-12-14...
# Data for 2020-12-14 written to apod_data.json.
# Fetching data for 2020-12-15...
# Data for 2020-12-15 written to apod_data.json.
# Fetching data for 2020-12-16...
# Data for 2020-12-16 written to apod_data.json.
# Fetching data for 2020-12-17...
# Data for 2020-12-17 written to apod_data.json.
# Fetching data for 2020-12-18...
# Data for 2020-12-18 written to apod_data.json.
# Fetching data for 2020-12-19...
# Data for 2020-12-19 written to apod_data.json.
# Fetching data for 2020-12-20...
# Data for 2020-12-20 written to apod_data.json.
# Fetching data for 2020-12-21...
# Data for 2020-12-21 written to apod_data.json.
# Fetching data for 2020-12-22...
# Data for 2020-12-22 written to apod_data.json.
# Fetching data for 2020-12-23...
# Data for 2020-12-23 written to apod_data.json.
# Fetching data for 2020-12-24...
# Data for 2020-12-24 written to apod_data.json.
# Fetching data for 2020-12-25...
# Data for 2020-12-25 written to apod_data.json.
# Fetching data for 2020-12-26...
# Data for 2020-12-26 written to apod_data.json.
# Fetching data for 2020-12-27...
# Data for 2020-12-27 written to apod_data.json.
# Fetching data for 2020-12-28...
# Data for 2020-12-28 written to apod_data.json.
# Fetching data for 2020-12-29...
# Data for 2020-12-29 written to apod_data.json.
# Fetching data for 2020-12-30...
# Data for 2020-12-30 written to apod_data.json.
# Fetching data for 2020-12-31...
# Data for 2020-12-31 written to apod_data.json.
# Data fetching completed. 365 records saved to apod_data.json.
# Data successfully retrieved and processed.
