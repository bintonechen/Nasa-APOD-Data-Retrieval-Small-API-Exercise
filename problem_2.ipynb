# %%
# Exercise 2: JSON Data Reading, Looping, and Processing 
# Date: Nov 16, 2024

# %%
import json
import csv

# %%
# 1. Reading and Loading JSON Data with Exception Handling 

def read_apod_data():
    
    # define the input JSON file
    input_file = "apod_data.json"
    
    try:
        # open and load the JSON file
        with open(input_file, "r") as file:
            data = json.load(file)
        
        # check if the file contains no data
        if not data:
            print("The file is empty. No data to display")
            return None
        
        # loop through the JSON data and date and title of each entry
        print("Apod DATA:")
        print("--------------------")
        for entry in data:
            date = entry.get("date", "N/A" )
            title = entry.get("title", "N/A")
            print(f"Date: {date}, Title: {title}")
        return data
    
    except FileNotFoundError:
        print(f"Error: The file '{input_file}' does not exist.")
        return None
    except PermissionError:
        print(f"Error: Permission denied to read the file '{input_file}'.")
        return None        
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# call the function   
data = read_apod_data()   

if data:
    print("\nData successfully loaded.")
    print("\nDate and title of each entry are displayed.")
else:
    print("\nNo data was loaded. Please check the error messages for detail.")
# Out:
# Apod DATA:
# --------------------
# Date: 2020-01-01, Title: Betelgeuse Imagined
# Date: 2020-01-02, Title: The Fainting of Betelgeuse
# Date: 2020-01-03, Title: Quadrantids over the Great Wall
# Date: 2020-01-04, Title: Aurora Slathers Up the Sky
# Date: 2020-01-05, Title: A Starry Night of Iceland
# Date: 2020-01-06, Title: Tumultuous Clouds of Jupiter
# Date: 2020-01-07, Title: IC 405: The Flaming Star Nebula
# Date: 2020-01-08, Title: Galaxies in the River
# Date: 2020-01-09, Title: Perihelion to Aphelion
# Date: 2020-01-10, Title: Nacreous Clouds over Sweden
# Date: 2020-01-11, Title: NGC 602 and Beyond
# Date: 2020-01-12, Title: Stars and Dust in Corona Australis
# Date: 2020-01-13, Title: A Desert Eclipse
# Date: 2020-01-14, Title: Evidence of an Active Volcano on Venus
# Date: 2020-01-15, Title: Iridescent Clouds over Sweden
# Date: 2020-01-16, Title: NGC 247 and Friends
# Date: 2020-01-17, Title: Apollo 17: A Stereo View from Lunar Orbit
# Date: 2020-01-18, Title: An Almost Eclipse of the Moon
# Date: 2020-01-19, Title: M1: The Incredible Expanding Crab Nebula
# Date: 2020-01-20, Title: Quadrantid Meteors through Orion
# Date: 2020-01-21, Title: Parker: Sounds of the Solar Wind
# Date: 2020-01-22, Title: The Hyades Star Cluster
# Date: 2020-01-23, Title: Globular Star Cluster NGC 6752
# Date: 2020-01-24, Title: Into the  Shadow
# Date: 2020-01-25, Title: Rubin's Galaxy
# Date: 2020-01-26, Title: Hills, Ridges, and Tracks on Mars
# Date: 2020-01-27, Title: Comet CG Evaporates
# Date: 2020-01-28, Title: Star Formation in the Tadpole Nebula
# Date: 2020-01-29, Title: Milky Way over Yellowstone
# Date: 2020-01-30, Title: Two Clusters and a Comet
# Date: 2020-01-31, Title: Goldilocks Zones and Stars
# Date: 2020-02-01, Title: Apollo 14 Heads for Home
# Date: 2020-02-02, Title: Zeta Oph: Runaway Star
# Date: 2020-02-03, Title: Solar Granules at Record High Resolution
# Date: 2020-02-04, Title: A Sunset Night Sky over the Grand Canyon
# Date: 2020-02-05, Title: Lunar Eclipse Perspectives
# Date: 2020-02-06, Title: Southern Moonscape
# Date: 2020-02-07, Title: NGC 7331 Close Up
# Date: 2020-02-08, Title: Cosmic Clouds in the Unicorn
# Date: 2020-02-09, Title: To Fly Free in Space
# Date: 2020-02-10, Title: Solar Eclipse over the UAE
# Date: 2020-02-11, Title: Launch of the Solar Orbiter
# Date: 2020-02-12, Title: Star Trails of the North and South
# Date: 2020-02-13, Title: Spitzer's Trifid
# Date: 2020-02-14, Title: The Pale Blue Dot
# Date: 2020-02-15, Title: Carina Nebula Close Up
# Date: 2020-02-16, Title: NGC 2392: Double-Shelled Planetary Nebula
# Date: 2020-02-17, Title: The Changing Surface of Fading Betelgeuse
# Date: 2020-02-18, Title: Orion over the Central Bohemian Highlands
# Date: 2020-02-19, Title: UGC 12591: The Fastest Rotating Galaxy Known
# Date: 2020-02-20, Title: Trifecta at Twilight
# Date: 2020-02-21, Title: LDN 1622: Dark Nebula in Orion
# Date: 2020-02-22, Title: Central Centaurus A
# Date: 2020-02-23, Title: Illustris Simulation of the Universe
# Date: 2020-02-24, Title: Moon Corona, Halo, and Arcs over Manitoba
# Date: 2020-02-25, Title: Jupiter's Magnetic Field from Juno
# Date: 2020-02-26, Title: NGTS-10b: Discovery of a Doomed Planet
# Date: 2020-02-27, Title: Two Hemisphere Night Sky
# Date: 2020-02-28, Title: South Celestial Rocket Launch
# Date: 2020-02-29, Title: Julius Caesar and Leap Days
# Date: 2020-03-01, Title: A Hole in Mars
# Date: 2020-03-02, Title: Sharpless-308: The Dolphin Nebula
# Date: 2020-03-03, Title: Apollo 13 Views of the Moon
# Date: 2020-03-04, Title: The Slow Dance of Galaxies NGC 5394 and 5395
# Date: 2020-03-05, Title: The Light, the Dark, and the Dusty
# Date: 2020-03-06, Title: Mars Panorama from Curiosity
# Date: 2020-03-07, Title: Pic du Midi Panorama
# Date: 2020-03-08, Title: Wolf-Rayet Star 124: Stellar Wind Machine
# Date: 2020-03-09, Title: Milky Way and Zodiacal Light over Chile
# Date: 2020-03-10, Title: Wide Field: Fox Fur, Unicorn, and Christmas Tree
# Date: 2020-03-11, Title: An Extreme Black Hole Outburst
# Date: 2020-03-12, Title: Falcon 9 Boostback
# Date: 2020-03-13, Title: Starry Night by Jean-Francois Millet
# Date: 2020-03-14, Title: Moonrise and Mountain Shadow
# Date: 2020-03-15, Title: The Snows of Churyumov-Gerasimenko
# Date: 2020-03-16, Title: A Moon Dressed Like Saturn
# Date: 2020-03-17, Title: M77: Spiral Galaxy with an Active Center
# Date: 2020-03-18, Title: Anticrepuscular Rays over Florida
# Date: 2020-03-19, Title: M13: The Great Globular Cluster in Hercules
# Date: 2020-03-20, Title: Morning, Planets, Moon and Montreal
# Date: 2020-03-21, Title: Comet ATLAS and the Mighty Galaxies
# Date: 2020-03-22, Title: Moon Setting Behind Teide Volcano
# Date: 2020-03-23, Title: From the Pleiades to the Eridanus Loop
# Date: 2020-03-24, Title: A Black Hole Disrupts a Passing Star
# Date: 2020-03-25, Title: Star Forming Region S106
# Date: 2020-03-26, Title: Andromeda Station
# Date: 2020-03-27, Title: A Little Drop of Galaxy
# Date: 2020-03-28, Title: Stars Trail over Ragusa
# Date: 2020-03-29, Title: A 212-Hour Exposure of Orion
# Date: 2020-03-30, Title: The Colors of Saturn from Cassini
# Date: 2020-03-31, Title: The Galactic Center from Radio to X-ray
# Date: 2020-04-01, Title: Asteroid or Potato?
# Date: 2020-04-02, Title: Venus and the Pleiades in April
# Date: 2020-04-03, Title: The Traffic in Taurus
# Date: 2020-04-04, Title: Venus and the Sisters
# Date: 2020-04-05, Title: Color the Universe
# Date: 2020-04-06, Title: NGC 1672: Barred Spiral Galaxy from Hubble
# Date: 2020-04-07, Title: A Path North
# Date: 2020-04-08, Title: Country Sky versus City Sky
# Date: 2020-04-09, Title: A Flow of Time
# Date: 2020-04-10, Title: Full Moon of Spring
# Date: 2020-04-11, Title: Venus and the Pleiades in April
# Date: 2020-04-12, Title: The Horsehead Nebula in Infrared from Hubble
# Date: 2020-04-13, Title: A Sailing Stone across Death Valley
# Date: 2020-04-14, Title: NGC 253: The Silver Coin Galaxy
# Date: 2020-04-15, Title: A Cosmic Triangle
# Date: 2020-04-16, Title: Comet ATLAS Breaks Up
# Date: 2020-04-17, Title: The Windmill and the Star Trails
# Date: 2020-04-18, Title: Just Another Day on Aerosol Earth
# Date: 2020-04-19, Title: Cassini Approaches Saturn
# Date: 2020-04-20, Title: IC 2944: The Running Chicken Nebula
# Date: 2020-04-21, Title: Eye on the Milky Way
# Date: 2020-04-22, Title: Planet Earth at Twilight
# Date: 2020-04-23, Title: Lyrid Meteor Streak
# Date: 2020-04-24, Title: Around the World at Night
# Date: 2020-04-25, Title: Hubble's Cosmic Reef
# Date: 2020-04-26, Title: Edwin Hubble Discovers the Universe
# Date: 2020-04-27, Title: Fresh Tiger Stripes on Saturn's Enceladus
# Date: 2020-04-28, Title: The Kepler-90 Planetary System
# Date: 2020-04-29, Title: The Ion Tail of New Comet SWAN
# Date: 2020-04-30, Title: Andromeda Island Universe
# Date: 2020-05-01, Title: A View Toward M106
# Date: 2020-05-02, Title: Radio, The Big Ear, and the Wow! Signal
# Date: 2020-05-03, Title: A Message from Earth
# Date: 2020-05-04, Title: Earth Flyby of BepiColombo
# Date: 2020-05-05, Title: Carina in Perspective
# Date: 2020-05-06, Title: LDN 1471: A Windblown Star Cavity
# Date: 2020-05-07, Title: Analemma of the Moon
# Date: 2020-05-08, Title: Long Tailed Comet SWAN
# Date: 2020-05-09, Title: Full Flower Moonrise
# Date: 2020-05-10, Title: The Porpoise Galaxy from Hubble
# Date: 2020-05-11, Title: Behind Betelgeuse
# Date: 2020-05-12, Title: Lyrid Meteors from the Constellation Lyra
# Date: 2020-05-13, Title: Jupiter in Infrared from Gemini
# Date: 2020-05-14, Title: Comet Halley vs Comet SWAN
# Date: 2020-05-15, Title: Galaxy Wars: M81 and M82
# Date: 2020-05-16, Title: The Dark River to Antares
# Date: 2020-05-17, Title: A Waterspout in Florida
# Date: 2020-05-18, Title: Journey into the Cosmic Reef
# Date: 2020-05-19, Title: Posters of the Solar System
# Date: 2020-05-20, Title: Moon, Mars, Saturn, Jupiter, Milky Way
# Date: 2020-05-21, Title: Phases of Venus
# Date: 2020-05-22, Title: South of Carina
# Date: 2020-05-23, Title: Ghost Fungus to Magellanic Cloud
# Date: 2020-05-24, Title: Valles Marineris: The Grand Canyon of Mars
# Date: 2020-05-25, Title: Mystic Mountain Monster being Destroyed
# Date: 2020-05-26, Title: The Milky Way over Snow-Capped Himalayas
# Date: 2020-05-27, Title: Earth and Moon through Saturn's Rings
# Date: 2020-05-28, Title: Reflecting the International Space Station
# Date: 2020-05-29, Title: Mercury Meets Crescent Venus
# Date: 2020-05-30, Title: Green Flashes: Sun, Moon, Venus, Mercury
# Date: 2020-05-31, Title: Aurora over Sweden
# Date: 2020-06-01, Title: The Lively Center of the Lagoon Nebula
# Date: 2020-06-02, Title: Novel Coronavirus Attacks Humanity
# Date: 2020-06-03, Title: The Dance of Venus and Earth
# Date: 2020-06-04, Title: Portrait of NGC 3628
# Date: 2020-06-05, Title: Dragon over Central Park
# Date: 2020-06-06, Title: Comet PanSTARRs and the Galaxies
# Date: 2020-06-07, Title: Halo of the Cat's Eye
# Date: 2020-06-08, Title: Atmospheric Ring of Venus
# Date: 2020-06-09, Title: Orion over Argentine Mountains
# Date: 2020-06-11, Title: Barred Spiral Galaxy NGC 1300
# Date: 2020-06-12, Title: NGC 2359: Thor's Helmet
# Date: 2020-06-13, Title: SpaceX Demo-2 Launch
# Date: 2020-06-14, Title: Happy People Dancing on Planet Earth
# Date: 2020-06-15, Title: A Ring of Fire Sunrise Solar Eclipse
# Date: 2020-06-16, Title: APOD is 25 Years Old Today
# Date: 2020-06-17, Title: Magnetic Streamlines of the Milky Way
# Date: 2020-06-18, Title: The Tadpoles of IC 410
# Date: 2020-06-19, Title: The Veins of Heaven
# Date: 2020-06-20, Title: Northern Summer on Titan
# Date: 2020-06-21, Title: Moon Occults Venus
# Date: 2020-06-22, Title: Moon Mountains Magnified during Ring of Fire Eclipse
# Date: 2020-06-23, Title: The X-Ray Sky from eROSITA
# Date: 2020-06-24, Title: Inverted City Beneath Clouds
# Date: 2020-06-25, Title: Eclipse Street, Hong Kong
# Date: 2020-06-26, Title: Eclipse under the Bamboo
# Date: 2020-06-27, Title: Eclipse under the ISS
# Date: 2020-06-28, Title: Europa and Jupiter from Voyager 1
# Date: 2020-06-29, Title: Dark Sky Reflections
# Date: 2020-06-30, Title: Bright Planetary Nebula NGC 7027 from Hubble
# Date: 2020-07-01, Title: Our Rotating Earth
# Date: 2020-07-02, Title: The Galaxy, the Planet, and the Apple Tree
# Date: 2020-07-03, Title: Lynds Dark Nebula 1251
# Date: 2020-07-04, Title: Meeting in the Mesosphere
# Date: 2020-07-05, Title: Saturn's Northern Hexagon
# Date: 2020-07-06, Title: M43: Dust, Gas, and Stars in the Orion Nebula
# Date: 2020-07-07, Title: Comet NEOWISE over Lebanon
# Date: 2020-07-08, Title: Mercury's Sodium Tail
# Date: 2020-07-09, Title: Noctilucent Clouds and Comet NEOWISE
# Date: 2020-07-10, Title: Comet NEOWISE from the ISS
# Date: 2020-07-11, Title: The Tails of Comet NEOWISE
# Date: 2020-07-12, Title: Comet CG Creates Its Dust Tail
# Date: 2020-07-13, Title: Comet NEOWISE Rising over the Adriatic Sea
# Date: 2020-07-14, Title: Comet NEOWISE over Stonehenge
# Date: 2020-07-15, Title: Comet NEOWISE over the Swiss Alps
# Date: 2020-07-16, Title: The Long Tails of Comet NEOWISE
# Date: 2020-07-17, Title: NEOWISE of the North
# Date: 2020-07-18, Title: Finding NEOWISE
# Date: 2020-07-19, Title: Rotating Moon from LRO
# Date: 2020-07-20, Title: Comet NEOWISE and Nebulae
# Date: 2020-07-21, Title: Iron in the Butterfly Nebula
# Date: 2020-07-22, Title: The Structured Tails of Comet NEOWISE
# Date: 2020-07-23, Title: Fairytale NEOWISE
# Date: 2020-07-24, Title: MAGIC NEOWISE
# Date: 2020-07-25, Title: Tianwen-1 Mission to Mars
# Date: 2020-07-26, Title: A Flight through the Hubble Ultra Deep Field
# Date: 2020-07-27, Title: Comet and Lightning Beyond Bighorn Mountains
# Date: 2020-07-28, Title: NGC 6188: The Dragons of Ara
# Date: 2020-07-29, Title: The Giants of Summer
# Date: 2020-07-30, Title: The Red Planet Mars
# Date: 2020-07-31, Title: Mars 2020 from 5,000 Feet
# Date: 2020-08-01, Title: The Elephant's Trunk Nebula in Cepheus
# Date: 2020-08-02, Title: Two Worlds, One Sun
# Date: 2020-08-03, Title: Comet NEOWISE over Vikos Gorge
# Date: 2020-08-04, Title: NGC 2442: Galaxy in Volans
# Date: 2020-08-05, Title: Picture Rocks Sun Dagger
# Date: 2020-08-06, Title: Messier 20 and 21
# Date: 2020-08-07, Title: The Pipe Nebula
# Date: 2020-08-08, Title: Crescent Saturn
# Date: 2020-08-09, Title: The Origin of Elements
# Date: 2020-08-10, Title: Perseids from Perseus
# Date: 2020-08-11, Title: Churning Clouds on Jupiter
# Date: 2020-08-12, Title: The Shifting Tails of Comet NEOWISE
# Date: 2020-08-13, Title: Jupiter and Saturn Rising Beyond Alien Throne Rock
# Date: 2020-08-14, Title: NGC 5189: An Unusually Complex Planetary Nebula
# Date: 2020-08-15, Title: Mars at the Moon's Edge
# Date: 2020-08-16, Title: NGC 6814: Grand Design Spiral Galaxy from Hubble
# Date: 2020-08-17, Title: Perseids Around the Milky Way
# Date: 2020-08-18, Title: TYC 8998-760-1: Multiple Planets around a Sun Like Star
# Date: 2020-08-19, Title: The Sun Rotating
# Date: 2020-08-20, Title: Seeing Titan
# Date: 2020-08-21, Title: Unwinding M51
# Date: 2020-08-22, Title: Yogi And Friends In 3D
# Date: 2020-08-23, Title: The Helix Nebula from Blanco and Hubble
# Date: 2020-08-24, Title: Crescent Moon HDR
# Date: 2020-08-25, Title: Visualization: A Black Hole Accretion Disk
# Date: 2020-08-26, Title: Cygnus Skyscape
# Date: 2020-08-27, Title: Shell Galaxies in Pisces
# Date: 2020-08-28, Title: The Valley of Orion
# Date: 2020-08-29, Title: Martian Chiaroscuro
# Date: 2020-08-30, Title: NGC 6357: Cathedral to Massive Stars
# Date: 2020-08-31, Title: SS 433: Binary Star Micro-Quasar
# Date: 2020-09-01, Title: Salt Water Remnants on Ceres
# Date: 2020-09-02, Title: Jupiter and the Moons
# Date: 2020-09-03, Title: A Halo for Andromeda
# Date: 2020-09-04, Title: The Wizard Nebula
# Date: 2020-09-05, Title: A Falcon 9 Moon
# Date: 2020-09-06, Title: M1: The Crab Nebula from Hubble
# Date: 2020-09-07, Title: The Milky Way over St Michael's Mount
# Date: 2020-09-08, Title: GW190521: Unexpected Black Holes Collide
# Date: 2020-09-09, Title: Pleiades: The Seven Sisters Star Cluster
# Date: 2020-09-10, Title: Jupiter's Swimming Storm
# Date: 2020-09-11, Title: The Reappearance of Mars
# Date: 2020-09-12, Title: A Thousand Meteors
# Date: 2020-09-13, Title: M2-9: Wings of a Butterfly Nebula
# Date: 2020-09-14, Title: Corn Moon Rising
# Date: 2020-09-15, Title: Biomarker Phosphine Discovered in the Atmosphere of Venus
# Date: 2020-09-16, Title: Gravel Ejected from Asteroid Bennu
# Date: 2020-09-17, Title: Solar Cycle 25 Has Begun
# Date: 2020-09-18, Title: Arp 78: Peculiar Galaxy in Aries
# Date: 2020-09-19, Title: Orion in Depth
# Date: 2020-09-20, Title: Breaking Distant Light
# Date: 2020-09-21, Title: Omega Sunrise
# Date: 2020-09-22, Title: Equinox in the Sky
# Date: 2020-09-23, Title: ISS Transits Mars
# Date: 2020-09-24, Title: Enceladus in Infrared
# Date: 2020-09-25, Title: Moon over Andromeda
# Date: 2020-09-26, Title: Moon Pairs and the Synodic Month
# Date: 2020-09-27, Title: Lightning over Colorado
# Date: 2020-09-28, Title: Filaments of the Cygnus Loop
# Date: 2020-09-29, Title: GW Orionis: A Star System with Tilted Rings
# Date: 2020-09-30, Title: Sonified: Eagle Nebula Pillars
# Date: 2020-10-01, Title: Solis Lacus: The Eye of Mars
# Date: 2020-10-02, Title: Biking to the Moon
# Date: 2020-10-03, Title: Driving to the Sun
# Date: 2020-10-04, Title: Orion Nebula in Oxygen, Hydrogen, and Sulfur
# Date: 2020-10-05, Title: NGC 5643: Nearby Spiral Galaxy from Hubble
# Date: 2020-10-06, Title: Mars Approach 2020
# Date: 2020-10-07, Title: Ou4: A Giant Squid in a Flying Bat
# Date: 2020-10-08, Title: Mare Frigoris
# Date: 2020-10-09, Title: The Very Large Array at Moonset
# Date: 2020-10-10, Title: Virgo Cluster Galaxies
# Date: 2020-10-11, Title: Milky Way over the Pinnacles in Australia
# Date: 2020-10-12, Title: Descending Toward Asteroid Bennu
# Date: 2020-10-13, Title: Mars, Pleiades, and Andromeda over Stone Lions
# Date: 2020-10-14, Title: The Colorful Clouds of Rho Ophiuchi
# Date: 2020-10-15, Title: Galaxies in Pegasus
# Date: 2020-10-16, Title: Planetary Nebula Abell 78
# Date: 2020-10-17, Title: Cygnus: Bubble and Crescent
# Date: 2020-10-18, Title: UGC 1810: Wildly Interacting Galaxy from Hubble
# Date: 2020-10-19, Title: A Flight over Jupiter Near the Great Red Spot
# Date: 2020-10-20, Title: Saturn and Jupiter over Italian Peaks
# Date: 2020-10-21, Title: A Night Sky Vista from Sardinia
# Date: 2020-10-22, Title: Tagging Bennu
# Date: 2020-10-23, Title: Supernova in NGC 2525
# Date: 2020-10-24, Title: Globular Star Cluster 47 Tuc
# Date: 2020-10-25, Title: Dark Matter in a Simulated Universe
# Date: 2020-10-26, Title: Reflections of the Ghost Nebula
# Date: 2020-10-27, Title: Venusian Volcano Imagined
# Date: 2020-10-28, Title: NGC 6357: The Lobster Nebula
# Date: 2020-10-29, Title: The Ghoul of IC 2118
# Date: 2020-10-30, Title: Fear and Dread: The Moons of Mars
# Date: 2020-10-31, Title: A Galaxy of Horrors
# Date: 2020-11-01, Title: In the Center of the Trifid Nebula
# Date: 2020-11-02, Title: Half Sun with Prominence
# Date: 2020-11-03, Title: Tagging Bennu: The Movie
# Date: 2020-11-04, Title: Fifty Gravitational Wave Events Illustrated
# Date: 2020-11-05, Title: North of Orion's Belt
# Date: 2020-11-06, Title: Moon over ISS
# Date: 2020-11-07, Title: The Hercules Cluster of Galaxies
# Date: 2020-11-08, Title: Martian Moon Phobos from Mars Express
# Date: 2020-11-09, Title: In Green Company: Aurora over Norway
# Date: 2020-11-10, Title: The Central Soul Nebula Without Stars
# Date: 2020-11-11, Title: Colors of the Moon
# Date: 2020-11-12, Title: Comet ATLAS and Orion's Belt
# Date: 2020-11-13, Title: The Tarantula Zone
# Date: 2020-11-14, Title: Venus, Mercury, and the Waning Moon
# Date: 2020-11-15, Title: Edge-On Galaxy NGC 5866
# Date: 2020-11-16, Title: Light and Glory over Crete
# Date: 2020-11-17, Title: A Glowing STEVE and the Milky Way
# Date: 2020-11-18, Title: A Double Star Cluster in Perseus
# Date: 2020-11-19, Title: Crew-1 Mission Launch Streak
# Date: 2020-11-20, Title: Global Map: Mars at Opposition
# Date: 2020-11-21, Title: Mars and Meteor over Jade Dragon Snow Mountain
# Date: 2020-11-22, Title: Dark Molecular Cloud Barnard 68
# Date: 2020-11-23, Title: A Jupiter Vista from Juno
# Date: 2020-11-24, Title: The Helix Nebula from CFHT
# Date: 2020-11-25, Title: Andromeda over Patagonia
# Date: 2020-11-26, Title: The Great Turkey Nebula
# Date: 2020-11-27, Title: Chang'e 5 Mission Launch
# Date: 2020-11-28, Title: NGC 6822: Barnard's Galaxy
# Date: 2020-11-29, Title: Verona Rupes: Tallest Known Cliff in the Solar System
# Date: 2020-11-30, Title: Cygnus Without Stars
# Date: 2020-12-01, Title: NGC 346: Star Forming Cluster in the SMC
# Date: 2020-12-02, Title: Eye of Moon
# Date: 2020-12-03, Title: The Antennae Galaxies in Collision
# Date: 2020-12-04, Title: Curly Spiral Galaxy M63
# Date: 2020-12-05, Title: Mons Rumker in the Ocean of Storms
# Date: 2020-12-06, Title: M16: Pillars of Star Creation
# Date: 2020-12-07, Title: Mammatus Clouds over Mount Rushmore
# Date: 2020-12-08, Title: Great Conjunction over Sicilian Lighthouse
# Date: 2020-12-09, Title: Arecibo Telescope Collapse
# Date: 2020-12-10, Title: Simeis 147: Supernova Remnant
# Date: 2020-12-11, Title: Messier Craters in Stereo
# Date: 2020-12-12, Title: Saturn and Jupiter in Summer 2020
# Date: 2020-12-13, Title: Geminid Meteors over Xinglong Observatory
# Date: 2020-12-14, Title: Capsule Returns from Asteroid Ryugu
# Date: 2020-12-15, Title: Great Conjunction: Saturn and Jupiter Converge
# Date: 2020-12-16, Title: Sonified: The Matter of the Bullet Cluster
# Date: 2020-12-17, Title: Gemini's Meteors
# Date: 2020-12-18, Title: Diamond in the Sky
# Date: 2020-12-19, Title: Conjunction after Sunset
# Date: 2020-12-20, Title: A Volcanic Great Conjunction
# Date: 2020-12-21, Title: Solstice: Sunrises Around the Year
# Date: 2020-12-22, Title: Trifid Pillars and Jets
# Date: 2020-12-23, Title: Jupiter Meets Saturn: A Red Spotted Great Conjunction
# Date: 2020-12-24, Title: Portrait of NGC 1055
# Date: 2020-12-25, Title: Northern Winter Night
# Date: 2020-12-26, Title: Fox Fur, Unicorn, and Christmas Tree
# Date: 2020-12-27, Title: Cosmic Latte: The Average Color of the Universe
# Date: 2020-12-28, Title: M16: Inside the Eagle Nebula
# Date: 2020-12-29, Title: Earth During a Total Solar Eclipse
# Date: 2020-12-30, Title: Jupiter and Saturn Great Conjunction: The Movie
# Date: 2020-12-31, Title: Trail of the Returner
#
# Data successfully loaded.
#
# Date and title of each entry are displayed.

# %%
# 2. Processing and Summarizing Data Using Loops 

def analyze_apod_media():
    
    input_file = "apod_data.json"
    
    try:
        # open and load the JSON file
        with open(input_file, "r") as file:
            data = json.load(file)
            
        # check if the file contains no data
        if not data:
            print("The file is empty. No data to display")
            return None
        
        # initialize counters and variables
        image_count = 0
        video_count = 0
        longest_explanation = ""
        longest_explanation_date = ""
        
        # loop through the JSON data and count the total number of images and videos    
        for entry in data:
            media_type = entry.get("media_type", "N/A").lower()
            explanation = entry.get("explanation", "N/A")
            date = entry.get("date", "N/A") 
            
            if media_type == "image":
                image_count +=1
            elif media_type == "video":
                video_count +=1
            
            if explanation != "N/A" and len(explanation) > len(longest_explanation):
                longest_explanation = explanation
                longest_explanation_date = date
            
        # print the summary
        print("APOD Data Analysis:")
        print("--------------------")
        print(f"Total Images: {image_count}")
        print(f"Total Videos: {video_count}")
        print(f"Date with the most detailed explanation: {longest_explanation_date}")
        print(f"Length of the Longest Explanation: {len(longest_explanation)}")
        
        # return the analysis results as a dictionary
        return {
            "total_images": image_count,
            "total_videos": video_count,
            "longest_explanation_date": longest_explanation_date,
            "longest_explanation_length": len(longest_explanation),
            "longest_explanation_text": longest_explanation
        }
        

    except FileNotFoundError:
        print(f"Error: The file '{input_file}' does not exist.")
    except PermissionError:
        print(f"Error: Permission denied to read the file '{input_file}'.")      
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# call the function    
result = analyze_apod_media()

if result:
    print("\nMedia analysis completed.")
else: 
    print("\nNo analysis was performed. Please check the error messages for details.")
# Out:
# APOD Data Analysis:
# --------------------
# Total Images: 329
# Total Videos: 36
# Date with the most detailed explanation: 2020-08-31
# Length of the Longest Explanation: 1572
#
# Media analysis completed.

# %%
# 3. Extracting and Writing Data to a CSV File 
def extract_and_write_to_csv():
    
    input_file = "apod_data.json"
    output_csv = "apod_summary.csv"
    
    try:
        # open and load the JSON file
        with open(input_file, "r") as file:
            data = json.load(file)
            
        # check if the file contains no data
        if not data:
            print("The file is empty. No data to display")
            return None
        
        # define the column names to extract and write to the CSV
        field_names = ["date", "title", "media_type", "url"]
        
        # open the CSV file in append mode and write records
        with open(output_csv, "a", newline="", encoding="utf-8") as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=field_names)
            
            # write header if the file is empty
            csvfile.seek(0, 2)  # Move to the end of the file
            if csvfile.tell() == 0:
                writer.writeheader()
            
            # loop through the JSON data and write to the CSV
            for entry in data:
                writer.writerow({
                    "date": entry.get("date", "N/A"),
                    "title": entry.get("title", "N/A"),
                    "media_type": entry.get("media_type", "N/A"),
                    "url": entry.get("url", "N/A")
                })
            
            print(f"Data written to {output_csv} successfully.")
        
        
    except FileNotFoundError:
        print(f"Error: The file '{input_file}' does not exist.")
    except PermissionError:
        print(f"Error: Permission denied to write to the file '{output_csv}'.")
    except json.JSONDecodeError:
        print(f"Error: The file '{input_file}' contains invalid JSON.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")       

# call the function  
extract_and_write_to_csv()
# Out:
# Data written to apod_summary.csv successfully.
